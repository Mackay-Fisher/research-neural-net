# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
import matplotlib.pyplot as plt

# %%
X = np.linspace(0,1,1000)
y = np.sqrt(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

# %%
model = keras.Sequential([
    keras.layers.Dense(140, activation = 'relu', kernel_initializer = 'random_normal', input_shape = (1,)),
    keras.layers.Dense(1)  
])

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error' )

# %%
e = 1000
model.fit(X_train, y_train, epochs=e)
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 0s 473us/step - loss: 0.3578
# Epoch 2/1000
# 25/25 [==============================] - 0s 440us/step - loss: 0.1221
# Epoch 3/1000
# 25/25 [==============================] - 0s 493us/step - loss: 0.0210
# Epoch 4/1000
# 25/25 [==============================] - 0s 462us/step - loss: 0.0069
# Epoch 5/1000
# 25/25 [==============================] - 0s 523us/step - loss: 0.0061
# Epoch 6/1000
# 25/25 [==============================] - 0s 484us/step - loss: 0.0055
# Epoch 7/1000
# 25/25 [==============================] - 0s 654us/step - loss: 0.0050
# Epoch 8/1000
# 25/25 [==============================] - 0s 666us/step - loss: 0.0045
# Epoch 9/1000
# 25/25 [==============================] - 0s 519us/step - loss: 0.0040
# Epoch 10/1000
# 25/25 [==============================] - 0s 488us/step - loss: 0.0036
# Epoch 11/1000
# 25/25 [==============================] - 0s 599us/step - loss: 0.0033
# Epoch 12/1000
# ...

# %%
X_train.shape
# Out:
# (800, 1)

# %%
val = model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 490us/step

# %%
plt.scatter(X_train, y_train)
plt.scatter(X_train, model.predict(X_train))
sorted_data = np.array(sorted(X_train, key=lambda x: x[0]))
print(sorted_data)
plt.plot(sorted_data, model.predict(sorted_data), color='red')
# Out:
# 25/25 [==============================] - 0s 386us/step
# [[0.        ]
#  [0.001001  ]
#  [0.002002  ]
#  [0.003003  ]
#  [0.00500501]
#  [0.00600601]
#  [0.00700701]
#  [0.00800801]
#  [0.00900901]
#  [0.01101101]
#  [0.01201201]
#  [0.01401401]
#  [0.01601602]
#  [0.01701702]
#  [0.01901902]
#  [0.02002002]
#  [0.02102102]
#  [0.02202202]
#  [0.02502503]
#  [0.02602603]
#  [0.02802803]
#  [0.02902903]
#  [0.03003003]
#  [0.03203203]
#  [0.03403403]
#  [0.03603604]
#  [0.03703704]
#  [0.03903904]
#  [0.04004004]
#  [0.04104104]
#  [0.04204204]
#  [0.04304304]
#  [0.04404404]
#  [0.04704705]
#  [0.04904905]
#  [0.05105105]
#  [0.05205205]
#  [0.05305305]
#  [0.05405405]
#  [0.05605606]
#  [0.05705706]
#  [0.05805806]
#  [0.05905906]
#  [0.06106106]
#  [0.06206206]
#  [0.06306306]
#  [0.06406406]
#  [0.06506507]
#  [0.06606607]
#  [0.06706707]
#  [0.06806807]
#  [0.06906907]
#  [0.07007007]
#  [0.07207207]
#  [0.07307307]
#  [0.07407407]
#  [0.07507508]
#  [0.07607608]
# ...
